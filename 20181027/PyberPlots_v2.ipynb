# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# reading the files for the analysis
cityOrig = pd.read_csv('city_data.csv')
rideOrig = pd.read_csv('ride_data.csv')

# %%
# combine the data into a single data set
combo = pd.merge(cityOrig, rideOrig, on='city')
combo_df = pd.DataFrame(combo)
combo_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
combo.dtypes
# Out:
# city             object
# driver_count      int64
# type             object
# date             object
# fare            float64
# ride_id           int64
# dtype: object

# %%
# totRides = combo_df['ride_id'].count()
# avgFare = combo_df['fare'].mean()
# numDrivers = combo_df['driver_count'].sum()

# combo_df['Total Rides'] = combo_df['ride_id'].count()
# combo_df['Average Fare'] = combo_df['fare'].mean()
# combo_df['No of Drivers'] = combo_df['driver_count'].sum()
combo_df.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# DO NOT DELETE!!!!!!!

plt.scatter(x, y, s=area, alpha=.5, color=['gold','lightskyblue','coral'],edgecolors='black')
plt.xlabel("Total Number of Rides (per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data (2016)")
plt.show()

# %%
# creating containers for the x, y, s values for scatter
# need to figure out the color situation - bookmarked names of colors >> how to assign to city_type??? 
# may need to pull in each city type separately and then combine into one scatter - yes
t_totRides = combo['ride_id'].count()
t_avgFare = combo['fare'].mean()
t_numDrivers = combo['driver_count'].sum()

x_urban = []
y_urban = []
area_urban = []

for data in combo:
    x_urban.append(t_totRides)
    y_urban.append(t_avgFare)
    area_urban.append(t_numDrivers / 3)

urban, = plt.scatter(x_urban, y_urban, s=area_urban, alpha=.5, color='coral', edgecolors='black')
#suburban, = plt.plot()
#rural, = plt.plot()
#plt.scatter(x, y, s=area, alpha=.5, color=['gold','lightskyblue','coral'],edgecolors='black')
plt.xlabel("Total Number of Rides (per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Ride Sharing Data (2016)")
plt.legend(loc="upper right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-15f2383c6236> in <module>()
#      15     area_urban.append(t_numDrivers / 3)
#      16
# ---> 17 urban, = plt.scatter(x_urban, y_urban, s=area_urban, alpha=.5, color='coral', edgecolors='black')
#      18 #suburban, = plt.plot()
#      19 #rural, = plt.plot()
#
# TypeError: 'PathCollection' object is not iterable
